# %% [markdown]
# <a href="https://colab.research.google.com/github/agubuffa/ProyectosData/blob/main/comisionesPermanentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importo librerias
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importo el archivo del mes que corresponda con las comisiones y leo el df
url="/content/drive/MyDrive/comisiones_octubre.csv"
df=pd.read_csv(url, sep=",")
df.head()
# Out:
#           Cuit  Productor            Nombre Productor          Fecha ingreso  \
# 0  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 1  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 2  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 3  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 4  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-05 00:00:00.0
#
#     Ingreso Origen Ingreso                                  Asegurado  Ramo  \
# 0  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 1  17077502           PAGF  CONS. DE PROP.: CHARCAS N* 1138 - CORDOBA     1
# 2  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 3  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 4  17073719           PAGF                    DONADIO EDGARDO GABRIEL     4
#
#      Póliza  Certificado  ...    Premio Comisión normal Comisión cobranza  \
# 0   1689536            0  ...    409.00           72.35               0.0
# 1   1630098            0  ...   1099.11          196.66               0.0
# 2   1689536            0  ...  36652.00         6588.67               0.0
# 3   1689536            0  ...    497.00           88.50               0.0
# 4  28525183            0  ...   5353.00          517.60               0.0
#
#   Comisión fomento Comisión otras Comisión total  Productor póliza  \
# 0              0.0            0.0          72.35             28787
# 1              0.0            0.0         196.66             28787
# 2              0.0            0.0        6588.67             28787
# 3              0.0            0.0          88.50             28787
# 4              0.0            0.0         517.60             28787
#
#    Remesa Self  Remesa productor  Cobrador
# 0   14570391.0               0.0       NaN
# 1   14570391.0               0.0       0.0
# 2   14570391.0               0.0       NaN
# 3   14570391.0               0.0       NaN
# 4   14567219.0               0.0       NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### ANALISIS EXPLORATORIO

# %%
#lo configuro para que se vean todas las columnas
pd.options.display.max_columns
pd.options.display.max_columns = None
df.head()
# Out:
#           Cuit  Productor            Nombre Productor          Fecha ingreso  \
# 0  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 1  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 2  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 3  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-07 00:00:00.0
# 4  20319010360      28787  GOMEZ GARDA RAFAEL AGUSTIN  2022-09-05 00:00:00.0
#
#     Ingreso Origen Ingreso                                  Asegurado  Ramo  \
# 0  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 1  17077502           PAGF  CONS. DE PROP.: CHARCAS N* 1138 - CORDOBA     1
# 2  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 3  17077502           PAGF                      ZITELLI NICOLAS ARIEL     1
# 4  17073719           PAGF                    DONADIO EDGARDO GABRIEL     4
#
#      Póliza  Certificado  Endoso   Fecha Emisión Endoso  \
# 0   1689536            0       3  2022-06-27 00:00:00.0
# 1   1630098            0       0  2021-10-27 00:00:00.0
# 2   1689536            0       0  2022-06-10 00:00:00.0
# 3   1689536            0       2  2022-06-24 00:00:00.0
# 4  28525183            0       2  2022-08-30 00:00:00.0
#
#    Fecha Vigencia Endoso Provincia Rol Moneda     Prima    Premio  \
# 0  2022-06-27 00:00:00.0   CORDOBA   P      $    206.72    409.00
# 1  2021-11-01 00:00:00.0   CORDOBA   P      $    595.93   1099.11
# 2  2022-06-01 00:00:00.0   CORDOBA   P      $  18824.77  36652.00
# 3  2022-06-24 00:00:00.0   CORDOBA   P      $    252.85    497.00
# 4  2022-09-08 00:00:00.0   CORDOBA   P      $   3044.71   5353.00
#
#    Comisión normal  Comisión cobranza  Comisión fomento  Comisión otras  \
# 0            72.35                0.0               0.0             0.0
# 1           196.66                0.0               0.0             0.0
# 2          6588.67                0.0               0.0             0.0
# 3            88.50                0.0               0.0             0.0
# 4           517.60                0.0               0.0             0.0
#
#    Comisión total  Productor póliza  Remesa Self  Remesa productor  Cobrador
# 0           72.35             28787   14570391.0               0.0       NaN
# 1          196.66             28787   14570391.0               0.0       0.0
# 2         6588.67             28787   14570391.0               0.0       NaN
# 3           88.50             28787   14570391.0               0.0       NaN
# 4          517.60             28787   14567219.0               0.0       NaN

# %%
#uso index para ver donde empieza donde finaliza y de cuanto en cuanto va. 
#uso info para ver el nombre de las columnas. me llama la atencion que no figura el num de cliente. 
#uso shape para ver cant de filas y cant de columnas. tengo 292 filas
#uso info para ver cada columna, cuantos datos no nulos tiene, y de que tipo es la columna

print(df.index)
print(df.columns)
print(df.shape) 
print(df.info())
# Out:
# RangeIndex(start=0, stop=356, step=1)
# Index(['Cuit', 'Productor', 'Nombre Productor', 'Fecha ingreso', 'Ingreso',
#        'Origen Ingreso', 'Asegurado', 'Ramo', 'Póliza', 'Certificado',
#        'Endoso', 'Fecha Emisión Endoso', 'Fecha Vigencia Endoso', 'Provincia',
#        'Rol', 'Moneda', 'Prima', 'Premio', 'Comisión normal',
#        'Comisión cobranza', 'Comisión fomento', 'Comisión otras',
#        'Comisión total', 'Productor póliza', 'Remesa Self', 'Remesa productor',
#        'Cobrador'],
#       dtype='object')
# (356, 27)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cuit                   356 non-null    int64
#  1   Productor              356 non-null    int64
#  2   Nombre Productor       356 non-null    object
#  3   Fecha ingreso          356 non-null    object
#  4   Ingreso                356 non-null    int64
#  5   Origen Ingreso         356 non-null    object
#  6   Asegurado              356 non-null    object
#  7   Ramo                   356 non-null    int64
#  8   Póliza                 356 non-null    int64
#  9   Certificado            356 non-null    int64
#  10  Endoso                 356 non-null    int64
#  11  Fecha Emisión Endoso   356 non-null    object
#  12  Fecha Vigencia Endoso  356 non-null    object
#  13  Provincia              356 non-null    object
#  14  Rol                    356 non-null    object
#  15  Moneda                 356 non-null    object
#  16  Prima                  356 non-null    float64
#  17  Premio                 356 non-null    float64
#  18  Comisión normal        356 non-null    float64
#  19  Comisión cobranza      356 non-null    float64
#  20  Comisión fomento       356 non-null    float64
#  21  Comisión otras         356 non-null    float64
#  22  Comisión total         356 non-null    float64
#  23  Productor póliza       356 non-null    int64
#  24  Remesa Self            107 non-null    float64
#  25  Remesa productor       107 non-null    float64
#  26  Cobrador               268 non-null    float64
# dtypes: float64(10), int64(8), object(9)
# memory usage: 75.2+ KB
# None

# %%
#aplico filtro para ver solo las columnas que me interesan
df_clean=df[['Asegurado', 'Ramo', 'Póliza','Comisión normal','Comisión total']]
df_clean.head(5)
# Out:
#                                    Asegurado  Ramo    Póliza  Comisión normal  \
# 0                      ZITELLI NICOLAS ARIEL     1   1689536            72.35
# 1  CONS. DE PROP.: CHARCAS N* 1138 - CORDOBA     1   1630098           196.66
# 2                      ZITELLI NICOLAS ARIEL     1   1689536          6588.67
# 3                      ZITELLI NICOLAS ARIEL     1   1689536            88.50
# 4                    DONADIO EDGARDO GABRIEL     4  28525183           517.60
#
#    Comisión total
# 0           72.35
# 1          196.66
# 2         6588.67
# 3           88.50
# 4          517.60

# %%
#renombro las columnas que tienen espacios y que tienen asentos. 

df_clean=df_clean.rename(columns={"Póliza":"Poliza","Comisión normal":"Comision_normal", "Comisión total":"Comision_total"})
df_clean.head(5)
# Out:
#                                    Asegurado  Ramo    Poliza  Comision_normal  \
# 0                      ZITELLI NICOLAS ARIEL     1   1689536            72.35
# 1  CONS. DE PROP.: CHARCAS N* 1138 - CORDOBA     1   1630098           196.66
# 2                      ZITELLI NICOLAS ARIEL     1   1689536          6588.67
# 3                      ZITELLI NICOLAS ARIEL     1   1689536            88.50
# 4                    DONADIO EDGARDO GABRIEL     4  28525183           517.60
#
#    Comision_total
# 0           72.35
# 1          196.66
# 2         6588.67
# 3           88.50
# 4          517.60

# %%
com_bruta=df_clean['Comision_total'].sum()
print(f'La comision bruta es= {com_bruta}')

com_neta= 76476
print(f'La comision neta es es= {com_neta}')

com_descuentos= 2000 + 22.50 + 1602
print(f'Los descuentos son= {com_descuentos}')
# Out:
# La comision bruta es= 77467.95000000001
# La comision neta es es= 76476
# Los descuentos son= 3624.5

# %% [markdown]
# ### COMISIONES GER BRAVO

# %%
list_g=["PEREZ HEREDIA EMANUEL RODRIGO", "PERICHAULT LEANDRO IVAN", "CONCI SOFIA EDITH", "BRAVO NATALIA SOLEDAD", 
         "PEREZ ROMERO ENRIQUE SERGIO", "PEREZ HEREDIA FACUNDO SERGIO", "CRUZ GABRIEL JUAN", "MORZONE AVILA MATHIAS EZEQUIEL", "asdas"]

# %%
len(list_g)
# Out:
# 9

# %%
for i in list_g:
  print(i)
  german1=df_clean[df_clean.Asegurado.isin([i])]
  #german2=df_clean['Asegurado'].isin([i])
# Out:
# PEREZ HEREDIA EMANUEL RODRIGO
# PERICHAULT LEANDRO IVAN
# CONCI SOFIA EDITH
# BRAVO NATALIA SOLEDAD
# PEREZ ROMERO ENRIQUE SERGIO
# PEREZ HEREDIA FACUNDO SERGIO
# CRUZ GABRIEL JUAN
# MORZONE AVILA MATHIAS EZEQUIEL
# asdas

# %%
german1.groupby(['Asegurado']).sum('Comision_total')
# Out:
# Empty DataFrame
# Columns: [Ramo, Poliza, Comision_normal, Comision_total]
# Index: []

# %%
#intento hacer el mismo filtro que en la celda anterior pero usando el metodo isin

german=df_clean[df_clean.Asegurado.isin(["PEREZ HEREDIA EMANUEL RODRIGO", "PERICHAULT LEANDRO IVAN", "CONCI SOFIA EDITH", "BRAVO NATALIA SOLEDAD", 
                                         "PEREZ ROMERO ENRIQUE SERGIO", "PEREZ HEREDIA FACUNDO SERGIO", "CRUZ GABRIEL JUAN", "MORZONE AVILA MATHIAS EZEQUIEL"])]
german.groupby(['Asegurado']).sum('Comision_total')
# Out:
#                                 Ramo     Poliza  Comision_normal  \
# Asegurado
# BRAVO NATALIA SOLEDAD             47   56666719           834.57
# CONCI SOFIA EDITH                 58   57393184           688.88
# CRUZ GABRIEL JUAN                 67   31212668           762.64
# MORZONE AVILA MATHIAS EZEQUIEL    35   61777042           955.68
# PEREZ HEREDIA EMANUEL RODRIGO     70  120639959          4092.00
# PEREZ HEREDIA FACUNDO SERGIO      35   61833319          1053.60
# PEREZ ROMERO ENRIQUE SERGIO       12    7159600           771.58
# PERICHAULT LEANDRO IVAN           35   60298749           814.04
#
#                                 Comision_total
# Asegurado
# BRAVO NATALIA SOLEDAD                   834.57
# CONCI SOFIA EDITH                       688.88
# CRUZ GABRIEL JUAN                       762.64
# MORZONE AVILA MATHIAS EZEQUIEL          955.68
# PEREZ HEREDIA EMANUEL RODRIGO          4092.00
# PEREZ HEREDIA FACUNDO SERGIO           1053.60
# PEREZ ROMERO ENRIQUE SERGIO             771.58
# PERICHAULT LEANDRO IVAN                 814.04

# %%
german.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 26 to 312
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Asegurado        25 non-null     object
#  1   Ramo             25 non-null     int64
#  2   Poliza           25 non-null     int64
#  3   Comision_normal  25 non-null     float64
#  4   Comision_total   25 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.2+ KB

# %%
german_filtro=german["Comision_total"].sum()
german_filtro
# Out:
# 9972.99

# %%
br=df_clean['Comision_total'].sum()
br
# Out:
# 77467.95000000001

# %%
#funcion de calculo de comisiones German
neto= 76476
bruto= br
costos= 2000 + 22.50 + 1602
def  calcula_g (bruto, costos):
    part_german= german_filtro/ bruto
    costos_german= part_german*costos
    neto_german= german_filtro - costos_german
    print("La participacion de germán en el total es: ", part_german)
    print("El costo atribuible a Germán del total es: ", costos_german)
    print("El monto de comisiones a transferir a Germán es: ", neto_german)
    return

calcula_g(bruto, costos)
# Out:
# La participacion de germán en el total es:  0.12873698090629734
# El costo atribuible a Germán del total es:  466.60718729487473
# El monto de comisiones a transferir a Germán es:  9506.382812705126

# %% [markdown]
# ### COMISIONES STEFI POSCA

# %%
#STEFI
# filtro todos sus asegurados del df

stefi=df_clean[df_clean.Asegurado.isin(["POSCA STEFANIA", "POSCA SEBASTIAN ALEJANDRO", "RAFFAELLI EDUARDO MARTIN", "ZAMBONI MARTA",
                                        "RUFFINI CARLA DANIELA", "DONEMBERG NADIR", "CORDOBA SILVINA ANDREA" , "MOTOS ZAMBONI OCTAVIO"])]
stefi.groupby('Asegurado').sum('Comision_total')
# Out:
#                            Ramo     Poliza  Comision_normal  Comision_total
# Asegurado
# CORDOBA SILVINA ANDREA       67   55841117           646.37          646.37
# DONEMBERG NADIR              94   58344102           760.76          760.76
# MOTOS ZAMBONI OCTAVIO       134  115048452             0.00            0.00
# POSCA SEBASTIAN ALEJANDRO    31   55136042           900.07          900.07
# POSCA STEFANIA               91   34443166           363.84          363.84
# RAFFAELLI EDUARDO MARTIN     39   31614401           397.28          397.28
# RUFFINI CARLA DANIELA        24    2891394           129.40          129.40
# ZAMBONI MARTA                94   58337246           543.85          543.85

# %%
#suma de las comisiones stefi
stefi_filtro=stefi["Comision_total"].sum()
stefi_filtro
# Out:
# 3741.57

# %%
#funcion de calculo de comisiones Stefi
def  calcula_s (bruto, costos):
    part_stefi= stefi_filtro/ bruto
    costos_stefi= part_stefi*costos
    neto_stefi= stefi_filtro - costos_stefi
    print("La participacion de Stefi en el total es: ", part_stefi)
    print("El costo atribuible a Stefi del total es: ", costos_stefi)
    print("El monto de comisiones a transferir a Stefi es: ", neto_stefi)
    return

calcula_s(bruto, costos)
# Out:
# La participacion de Stefi en el total es:  0.04829829626316431
# El costo atribuible a Stefi del total es:  175.05717480583903
# El monto de comisiones a transferir a Stefi es:  3566.512825194161

# %% [markdown]
# ### COMISIONES CARO ROURA

# %%
#CARO
# filtro todos sus asegurados del df

caro=df_clean[df_clean.Poliza.isin(["28625907"])]
caro
# Out:
# Empty DataFrame
# Columns: [Asegurado, Ramo, Poliza, Comision_normal, Comision_total]
# Index: []

# %%
caro.head()
# Out:
# Empty DataFrame
# Columns: [Asegurado, Ramo, Poliza, Comision_normal, Comision_total]
# Index: []

# %%
#suma de las comisiones stefi
caro_filtro=caro["Comision_total"].sum()
caro_filtro
# Out:
# 0.0

# %%
#funcion de calculo de comisiones Stefi
def  calcula_s (bruto, costos):
    part_caro= caro_filtro/ bruto
    costos_caro= part_caro*costos
    neto_caro= caro_filtro - costos_caro
    print("La participacion de Caro  en el total es: ", part_caro)
    print("El costo atribuible a Caro del total es: ", costos_caro)
    print("El monto de comisiones a transferir a Caro es: ", neto_caro)
    return

calcula_s(32588.78, 2161.77)
# Out:
# La participacion de Caro  en el total es:  0.0
# El costo atribuible a Caro del total es:  0.0
# El monto de comisiones a transferir a Caro es:  0.0

# %% [markdown]
# ### Comisiones Agus Buffa

# %%
#left_df.merge(right_df, on='user_id', how='left')


agus= df_clean.merge(german, on='Asegurado', how='left_only')
agus
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-d1c130cbdbc4> in <module>
#       2
#       3
# ----> 4 agus= df_clean.merge(german, on='Asegurado', how='left_only')
#       5 agus
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9201             copy=copy,
#    9202             indicator=indicator,
# -> 9203             validate=validate,
#    9204         )
#    9205
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     119         validate=validate,
#     120     )
# --> 121     return op.get_result()
#     122
#     123
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in get_result(self)
#     713             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     714
# --> 715         join_index, left_indexer, right_indexer = self._get_join_info()
#     716
#     717         llabels, rlabels = _items_overlap_with_suffix(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     964             )
#     965         else:
# --> 966             (left_indexer, right_indexer) = self._get_join_indexers()
#     967
#     968             if self.right_index:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _get_join_indexers(self)
#     939         # Both returned ndarrays are np.intp
#     940         return get_join_indexers(
# --> 941             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     942         )
#     943
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1501         )[::-1],
#    1502         "outer": libjoin.full_outer_join,
# -> 1503     }[how]
#    1504
#    1505     # error: Cannot call function of unknown type
#
# KeyError: 'left_only'
